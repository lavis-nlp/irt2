# %%
# used to dynamically explore where to make concept splits
# %load_ext autoreload
# %autoreload 2

# %%
import irt2

from irt2.graph import Graph
from irt2.graph import load_graph
from irt2.types import RID

from ktz.collections import ryaml

# from pprint import pprint

config = ryaml(
    irt2.ENV.DIR.CONF / 'create' / 'cde.yaml',
    irt2.ENV.DIR.CONF / 'create' / 'cde-l.yaml',
)

graph = load_graph(
    config['graph loader'],
    config['graph name'],
    *[irt2.ENV.DIR.ROOT / path for path in config['graph loader args']],
    **{k: irt2.ENV.DIR.ROOT / path for k, path in config['graph loader kwargs'].items()},
)

# pprint(config)
# print()
# print(graph.description)

# %%
from irt2.graph import Relation

relations = Relation.from_graph(graph)
print(f'got {len(relations)} relations')
# Out:
# CodEx-M
# got 51 relations

# %%
from tabulate import tabulate


def relation_table(relations):
    headers = '#', 'name', 'rid', 'ratio', '#heads', '#tails', '#triples'
    rows = []
    for no, rel in enumerate(relations, 1):
        rows.append((no, rel.name, rel.rid, rel.ratio, len(rel.heads), len(rel.tails), len(rel.triples)))

    return tabulate(rows, headers=headers)


print(relation_table(relations))
# Out:
#   #  name                                                       rid       ratio    #heads    #tails    #triples
# ---  -------------------------------------------------------  -----  ----------  --------  --------  ----------
#   1  P1412:languages spoken, written, or signed                  11  0.00631622      9816        62       12584
#   2  P1303:instrument                                            14  0.0104914       3622        38        6076
#   3  P140:religion                                               25  0.015873        2520        40        2651
#   4  P27:country of citizenship                                   3  0.0168763      13036       220       16828
#   5  P30:continent                                               19  0.01983          353         7         391
#   6  P509:cause of death                                          8  0.0201889       3071        62        3210
#   7  P172:ethnic group                                            5  0.0248385       2013        50        2293
#   8  P2348:time period                                           41  0.0263158        152         4         152
#   9  P102:member of political party                              20  0.0275862       2175        60        2668
#  10  P106:occupation                                              2  0.028528       13145       375       71596
#  11  P495:country of origin                                      18  0.0384911       1299        50        2049
#  12  P136:genre                                                  10  0.0431831       5303       229       11761
#  13  P641:sport                                                  26  0.0442708        384        17         418
#  14  P19:place of birth                                          13  0.0610995       7185       439        7214
#  15  P69:educated at                                              4  0.0647493       6502       421        9752
#  16  P463:member of                                               1  0.0677463       3705       251       11490
#  17  P264:record label                                           17  0.0684316       2002       137        3456
#  18  P20:place of death                                          22  0.0695957       5417       377        5442
#  19  P1050:medical condition                                     32  0.0759494        395        30         408
#  20  P101:field of work                                          27  0.0813421       1967       160        2421
#  21  P2283:uses                                                  45  0.0833333         12         1          12
#  22  P135:movement                                               16  0.0920097        413        38         446
#  23  P119:place of burial                                        24  0.0967078       1944       188        1972
#  24  P108:employer                                               15  0.126658        3016       382        4795
#  25  P37:official language                                       35  0.183007         306        56         403
#  26  P840:narrative location                                      6  0.196755         986       194        1506
#  27  P17:country                                                  9  0.223089         641       143        1323
#  28  P50:author                                                  43  0.235294           4        17          17
#  29  P452:industry                                               44  0.25              16         4          17
#  30  P551:residence                                              21  0.251753        1426       359        1934
#  31  P749:parent organization                                    38  0.315068          73        23          82
#  32  P407:language of work or name                               34  0.323529          34        11          43
#  33  P361:part of                                                39  0.347826         138        48         171
#  34  P57:director                                                28  0.370849         542       201         561
#  35  P159:headquarters location                                  12  0.420382         157        66         169
#  36  P161:cast member                                             0  0.479859        1227      2557        9249
#  37  P1056:product or material produced                          49  0.5                2         1           2
#  38  P740:location of formation                                  40  0.518797         133        69         133
#  39  P131:located in the administrative terroritorial entity     37  0.760736         163       124         212
#  40  P737:influenced by                                          23  0.871186         514       590        1508
#  41  P138:named after                                            42  0.890909          49        55          57
#  42  P112:founded by                                             36  0.948276          55        58          67
#  43  P40:child                                                   30  0.953704         309       324         391
#  44  P451:unmarried partner                                      31  0.961877         328       341         393
#  45  P530:diplomatic relation                                     7  0.968326         214       221        6225
#  46  P3373:sibling                                               29  0.994949         394       396         785
#  47  P26:spouse                                                  33  1                804       804         866
#  48  P3095:practiced by                                          46  1                  2         2           2
#  49  P54:member of sports team                                   47  1                  2         2           2
#  50  P113:airline hub                                            48  1                  1         1           1
#  51  P780:symptoms                                               50  1                  1         1           1

# %%
from itertools import islice

def print_relation_examples(graph, relations, n: int = 5):
    for rel in relations:
        print(f'{rel.ratio:2.3f} {rel.name} (rid={rel.rid})')
        for h, t, r in islice(graph.find(edges={rel.rid}), n):
            # print(h.split(':')[1])
            head = graph.source.ents[h].split(':')[1]
            tail = graph.source.ents[t].split(':')[1]

            print(' ' * 4 + f'{head} → {tail}')

    
print_relation_examples(graph, relations)
# Out:
# 0.006 P1412:languages spoken, written, or signed (rid=11)
#     Pedro Antonio de Alarcón → Spanish
#     Tamara Bunke → Russian
#     George Fenton → English
#     Giorgio Gaber → Italian
#     Louis Garrel → French
# 0.010 P1303:instrument (rid=14)
#     Alexander Ludwig → voice
#     Ferruccio Busoni → piano
#     Karel Vacek → clarinet
#     Siegfried Palm → cello
#     Tito Gobbi → voice
# 0.016 P140:religion (rid=25)
#     Errico Malatesta → atheism
#     Oriana Fallaci → atheism
#     Tarja Halonen → Lutheranism
#     John Keats → Anglicanism
#     Paul Hindemith → Lutheranism
# 0.017 P27:country of citizenship (rid=3)
#     Cardinal Richelieu → France
#     Wolfgang Golther → Germany
#     Robert Siewert → Germany
#     Hanns-Josef Ortheil → Germany
#     Heinrich von Wild → Switzerland
# 0.020 P30:continent (rid=19)
#     Honduras → North America
#     North Macedonia → Europe
#     Bhutan → Asia
#     Wales → Europe
#     South Sudan → Africa
# 0.020 P509:cause of death (rid=8)
#     John Balance → fall
#     Ronnie Van Zant → traffic collision
#     S. Yizhar → cardiovascular disease
#     Art Tatum → renal insufficiency
#     Leonid Gaidai → pulmonary embolism
# 0.025 P172:ethnic group (rid=5)
#     McCoy Tyner → African Americans
#     Viktor Dyk → Czechs
#     Jada Pinkett Smith → African Americans
#     Ennio Flaiano → Italians
#     Negotino → Bosniaks
# 0.026 P2348:time period (rid=41)
#     Rahel Sanzara → 20th century
#     Sidney Poitier → 20th century
#     Apollodorus of Damascus → Roman Empire
#     Lucian of Samosata → Roman Empire
#     Marilou → 21st century
# 0.028 P102:member of political party (rid=20)
#     Ted Nugent → Republican Party
#     Hermann Weber → Communist Party of Germany
#     Bill Frist → Republican Party
#     Oswald Pohl → Nazi Party
#     Lea Grundig → Communist Party of Germany
# 0.029 P106:occupation (rid=2)
#     Émile Proulx-Cloutier → songwriter
#     Vince Vaughn → television producer
#     Lisa Kudrow → writer
#     50 Cent → composer
#     Peter Cushing → painter
# 0.038 P495:country of origin (rid=18)
#     These Three → United States of America
#     Stop! Or My Mom Will Shoot → United States of America
#     Barney's Version → Canada
#     1492 – Conquest of Paradise → United Kingdom
#     Blade II → United States of America
# 0.043 P136:genre (rid=10)
#     Lisa Lopes → dance music
#     Claude François → disco
#     The Bride → horror film
#     Gianni Morandi → electronic dance music
#     Heart and Souls → fantasy film
# 0.044 P641:sport (rid=26)
#     Götz Otto → auto racing
#     Forest Whitaker → karate
#     Bill Monroe → baseball
#     Olivia Munn → taekwondo
#     Fran Healy → karate
# 0.061 P19:place of birth (rid=13)
#     Frank Stokes → Tennessee
#     Michael Bennett → Buffalo
#     Edmund Hoefer → Greifswald
#     Kenneth N. Stevens → Toronto
#     Danny Blanchflower → Belfast
# 0.065 P69:educated at (rid=4)
#     Karolos Papoulias → University of Cologne
#     Andrew Grove → City University of New York
#     Siméon Denis Poisson → École Polytechnique
#     Whit Bissell → University of North Carolina at Chapel Hill
#     Pavel Kohout → Charles University
# 0.068 P463:member of (rid=1)
#     Gustav Victor Rudolf Born → Royal Society
#     Julius Adams Stratton → National Academy of Sciences
#     Donald Knuth → American Academy of Arts and Sciences
#     Mauritania → Organisation for the Prohibition of Chemical Weapons
#     Vitaly Ginzburg → Russian Academy of Sciences
# 0.068 P264:record label (rid=17)
#     Brad Delson → Warner Bros. Records
#     Iggy Pop → I.R.S. Records
#     Katharine McPhee → 19 Recordings
#     Samantha Womack → Sony Music
#     Anne Murray → Liberty
# 0.070 P20:place of death (rid=22)
#     Henry Adams → Washington, D.C.
#     Walter Boehlich → Hamburg
#     Georg Waitz → Berlin
#     Hans Aumeier → Kraków
#     Marietta Shaginyan → Moscow
# 0.076 P1050:medical condition (rid=32)
#     Alfred Jarry → tuberculosis
#     Alfred Nobel → epilepsy
#     Julian Huxley → bipolar disorder
#     Max Weber → 1918-1920 flu pandemic
#     John Roberts → epilepsy
# 0.081 P101:field of work (rid=27)
#     Naomi Shemer → poetry
#     John Latham → art of painting
#     Jill Scott → poetry
#     Walter E. Massey → theoretical physics
#     Theodosius Dobzhansky → zoology
# 0.083 P2283:uses (rid=45)
#     Kingdom of Heaven → MASSIVE
#     The Lord of the Rings → MASSIVE
#     Live Free or Die Hard → MASSIVE
#     King Kong → MASSIVE
#     2012 → MASSIVE
# 0.092 P135:movement (rid=16)
#     Emily Brontë → Romanticism
#     Philip Pullman → atheism
#     Charles-Valentin Alkan → classical music
#     Jules Vallès → free-thought
#     Theo van Doesburg → expressionism
# 0.097 P119:place of burial (rid=24)
#     Ivan Petrov → Kuntsevo Cemetery
#     Theo Lingen → Zentralfriedhof (Vienna)
#     Franz Miklosich → Zentralfriedhof (Vienna)
#     Dalida → Montmartre Cemetery
#     Jean Paul → Bayreuth
# 0.127 P108:employer (rid=15)
#     Albert Einstein → Charles University
#     Cardinal Mazarin → Sapienza University of Rome
#     Kal Penn → University of Pennsylvania
#     Fred Brooks → IBM
#     Anatoly Karpov → Saint Petersburg State University
# 0.183 P37:official language (rid=35)
#     Suriname → Dutch
#     Nicaragua → Spanish
#     Polish–Lithuanian Commonwealth → Polish
#     Niue → English
#     South Korea → Korean
# 0.197 P840:narrative location (rid=6)
#     The Notorious Bettie Page → New York City
#     The Gift → Georgia
#     Chariots of Fire → England
#     Never Say Never Again → Bahamas
#     War of the Worlds → New York
# 0.223 P17:country (rid=9)
#     Priority Records → United States of America
#     Yerevan → Soviet Union
#     Kavadarci → Ottoman Empire
#     Gerasimov Institute of Cinematography → Russia
#     Zwickau → Soviet occupation zone
# 0.235 P50:author (rid=43)
#     Duch Německa → Friedrich Schiller
#     Duch Německa → August von Platen-Hallermünde
#     Duch Německa → Felix Dahn
#     Duch Německa → Friedrich Wilhelm Weber
#     Duch Německa → Gottfried August Bürger
# 0.250 P452:industry (rid=44)
#     ANTI- → music industry
#     Máximo Records → music industry
#     Arista → music industry
#     Bad Boy Records → music industry
#     EMI Records → music
# 0.252 P551:residence (rid=21)
#     Zygmunt Mineyko → France
#     Georg Gradnauer → Kleinmachnow
#     Mika Vainio → Oslo
#     Michael Bloomberg → Manhattan
#     Jean Reno → Los Angeles
# 0.315 P749:parent organization (rid=38)
#     Interscope Records → Universal Music Group
#     British Academy → Royal Society
#     EMI → Universal Music Group
#     Aftermath Entertainment → Universal Music Group
#     Mute Records → BMG Rights Management
# 0.324 P407:language of work or name (rid=34)
#     Band of Brothers → English
#     No Direction Home → English
#     It → English
#     North and South → English
#     NEKOPARA OVA → Portuguese
# 0.348 P361:part of (rid=39)
#     Kuwait → Middle East
#     Al Kooper → Blood, Sweat & Tears
#     Glen Campbell → The Beach Boys
#     New York University Tisch School of the Arts → New York University
#     Paraguay → Latin America
# 0.371 P57:director (rid=28)
#     Lost in Translation → Sofia Coppola
#     Singles → Cameron Crowe
#     Oscar → John Landis
#     The Impostors → Stanley Tucci
#     Men in Black → Barry Sonnenfeld
# 0.420 P159:headquarters location (rid=12)
#     EMI Records → United Kingdom
#     Rupert Murdoch → New York City
#     Lee Strasberg Theatre and Film Institute → Manhattan
#     Russian Academy of Sciences → Moscow
#     Slovenian Academy of Sciences and Arts → Ljubljana
# 0.480 P161:cast member (rid=0)
#     The Others → Keith Allen
#     Vicky Cristina Barcelona → Penélope Cruz
#     Frantic → John Mahoney
#     The Impostors → Allison Janney
#     The Phantom of the Opera → Minnie Driver
# 0.500 P1056:product or material produced (rid=49)
#     Sony Music → music
#     Sony BMG → music
# 0.519 P740:location of formation (rid=40)
#     Sting → England
#     EMI → London
#     Roxy Music → London
#     Soulja Boy → Atlanta
#     Barclay → Paris
# 0.761 P131:located in the administrative terroritorial entity (rid=37)
#     Mount Herzl → Jerusalem
#     Seoul → South Korea
#     Hochschule für Musik und Theater München → Munich
#     Vienna → Austria-Hungary
#     Baltimore → Maryland
# 0.871 P737:influenced by (rid=23)
#     Big Sean → Kanye West
#     Dorothy L. Sayers → G. K. Chesterton
#     Ursula K. Le Guin → Virgil
#     Joaquim Maria Machado de Assis → Johann Wolfgang von Goethe
#     T. S. Eliot → Stéphane Mallarmé
# 0.891 P138:named after (rid=42)
#     Charleston → Charles II of England
#     Jefferson Davis → Thomas Jefferson
#     Portsmouth → Portsmouth
#     ABBA → Benny Andersson
#     Madison → James Madison
# 0.948 P112:founded by (rid=36)
#     Reprise Records → Frank Sinatra
#     Arista → Clive Davis
#     American Recordings → Rick Rubin
#     Caroline Records → Richard Branson
#     Lee Strasberg Theatre and Film Institute → Lee Strasberg
# 0.954 P40:child (rid=30)
#     Martin Sheen → Emilio Estevez
#     Philippe de Rothschild → Philippine de Rothschild
#     Francis Ford Coppola → Sofia Coppola
#     Katherine Jackson → Rebbie Jackson
#     Bruce Dern → Laura Dern
# 0.962 P451:unmarried partner (rid=31)
#     Mia Farrow → Woody Allen
#     Mila Kunis → Macaulay Culkin
#     Sebastian Koch → Carice van Houten
#     Balthazar Getty → Sienna Miller
#     Carice van Houten → Guy Pearce
# 0.968 P530:diplomatic relation (rid=7)
#     Taiwan → Serbia
#     Germany → South Korea
#     Russia → Syria
#     Canada → Burkina Faso
#     Kazakhstan → Pakistan
# 0.995 P3373:sibling (rid=29)
#     Jamie Bamber → Anastasia Griffith
#     Keyne → Dwynwen
#     Ahmed bin Abdulaziz Al Saud → Fahd bin Abdulaziz Al Saud
#     Ève Curie → Irène Joliot-Curie
#     Willow Smith → Jaden Smith
# 1.000 P26:spouse (rid=33)
#     Jules Dassin → Melina Mercouri
#     Margarete Mitscherlich-Nielsen → Alexander Mitscherlich
#     Bella Akhmadulina → Yevgeny Yevtushenko
#     Robin Thicke → Paula Patton
#     Ronee Blakley → Wim Wenders
# 1.000 P3095:practiced by (rid=46)
#     Judaism → Jewish people
#     Christianity → Christian
# 1.000 P54:member of sports team (rid=47)
#     James Naismith → University of Kansas
#     Wilt Chamberlain → Philippines
# 1.000 P113:airline hub (rid=48)
#     Norwegian Air Shuttle → Rome
# 1.000 P780:symptoms (rid=50)
#     COVID-19 → respiratory failure

# %%
def print_relation(graph, relations, rid: RID, maxn: int = None):
    rel = [rel for rel in relations if rel.rid == rid][0]
    print(str(rel))

    print(f"showing {str(maxn) if maxn is not None else 'all'} triples:")
    triples = rel.triples if maxn is None else list(rel.triples)[:maxn]

    print(graph.tabulate_triples(triples))


# these relations are exluded from entry in irt2
for rid in {43, 46, 47, 48, 49, 50}:
    print('\n', '-' * 80, '\n')
    print_relation(graph=graph, relations=relations, rid=rid)
# Out:
#  --------------------------------------------------------------------------------
#
# P50:author (43): ratio=0.23529 (heads=4, tails=17) 17 triples
# showing all triples:
#        head                             tail                                      relation
# -----  ------------------------  -----  ------------------------------------  --  ----------
#  5974  Q26162388:Duch Německa     9718  Q22670:Friedrich Schiller             43  P50:author
#  5974  Q26162388:Duch Německa    12531  Q62432:August von Platen-Hallermünde  43  P50:author
#  5974  Q26162388:Duch Německa     1613  Q61456:Felix Dahn                     43  P50:author
#  5974  Q26162388:Duch Německa    11571  Q77492:Friedrich Wilhelm Weber        43  P50:author
#  5974  Q26162388:Duch Německa     4977  Q213675:Gottfried August Bürger       43  P50:author
#  5974  Q26162388:Duch Německa     5448  Q44403:Heinrich Heine                 43  P50:author
#  1760  Q190050:Fight Club         7611  Q268181:Chuck Palahniuk               43  P50:author
# 16372  Q102754:Dr. No             8514  Q82104:Ian Fleming                    43  P50:author
#  5974  Q26162388:Duch Německa     5975  Q63699:Eduard Mörike                  43  P50:author
#  5974  Q26162388:Duch Německa     1410  Q9358:Friedrich Nietzsche             43  P50:author
#  5974  Q26162388:Duch Německa     6473  Q154367:Friedrich Gottlieb Klopstock  43  P50:author
#  5974  Q26162388:Duch Německa     4708  Q71616:Max von Schenkendorf           43  P50:author
#  5974  Q26162388:Duch Německa    11466  Q61058:Ludwig Uhland                  43  P50:author
# 10247  Q208048:Band of Brothers   5295  Q2263:Tom Hanks                       43  P50:author
#  5974  Q26162388:Duch Německa      351  Q5879:Johann Wolfgang von Goethe      43  P50:author
#  5974  Q26162388:Duch Německa    16869  Q60684:Novalis                        43  P50:author
#  5974  Q26162388:Duch Německa     3188  Q78437:Ernst Bertram                  43  P50:author
#
#  --------------------------------------------------------------------------------
#
# P3095:practiced by (46): ratio=1.00000 (heads=2, tails=2) 2 triples
# showing all triples:
#       head                       tail                     relation
# ----  ------------------  -----  -------------------  --  ------------------
# 1182  Q9268:Judaism         281  Q7325:Jewish people  46  P3095:practiced by
#  893  Q5043:Christianity  16508  Q106039:Christian    46  P3095:practiced by
#
#  --------------------------------------------------------------------------------
#
# P54:member of sports team (47): ratio=1.00000 (heads=2, tails=2) 2 triples
# showing all triples:
#        head                            tail                             relation
# -----  ------------------------  ----  ---------------------------  --  -------------------------
# 11198  Q188962:James Naismith     513  Q52413:University of Kansas  47  P54:member of sports team
#  6244  Q182455:Wilt Chamberlain  6219  Q928:Philippines             47  P54:member of sports team
#
#  --------------------------------------------------------------------------------
#
# P113:airline hub (48): ratio=1.00000 (heads=1, tails=1) 1 triples
# showing all triples:
#       head                                tail           relation
# ----  -----------------------------  ---  ---------  --  ----------------
# 2297  Q215392:Norwegian Air Shuttle  617  Q220:Rome  48  P113:airline hub
#
#  --------------------------------------------------------------------------------
#
# P1056:product or material produced (49): ratio=0.50000 (heads=2, tails=1) 2 triples
# showing all triples:
#       head                         tail            relation
# ----  --------------------  -----  ----------  --  ----------------------------------
# 8628  Q56760250:Sony Music  10966  Q638:music  49  P1056:product or material produced
#  793  Q3001888:Sony BMG     10966  Q638:music  49  P1056:product or material produced
#
#  --------------------------------------------------------------------------------
#
# P780:symptoms (50): ratio=1.00000 (heads=1, tails=1) 1 triples
# showing all triples:
#       head                      tail                             relation
# ----  ------------------  ----  ---------------------------  --  -------------
# 9874  Q84263196:COVID-19  5540  Q767485:respiratory failure  50  P780:symptoms
